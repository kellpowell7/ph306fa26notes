# %% [markdown]
# <a href="https://colab.research.google.com/github/kellpowell7/ph306fa26notes/blob/main/ph306_08192026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
from astropy import units as u
from astropy.units import Quantity as Q
EARTH_GRAVITY = u.Quantity(9.81, u.m/u.s**2)
EARTH_GRAVITY.to(u.imperial.ft/u.s**2)
# Out:
# <Quantity 32.18503937 ft / s2>
